# %%
zipped # run this cell to view list
# Out:
# [('overall_qual_1', -0.0),
#  ('overall_qual_2', 0.0),
#  ('overall_qual_3', -0.0),
#  ('overall_qual_4', -313.0025984055022),
#  ('overall_qual_5', -923.4721096586177),
#  ('overall_qual_6', -0.0),
#  ('overall_qual_7', 3222.4340490653994),
#  ('overall_qual_8', 7770.8582115227255),
#  ('overall_qual_9', 9717.152022229793),
#  ('overall_qual_10', 8568.35765397452),
#  ('utilities_AllPub', 0.0),
#  ('neighborhood_Blmngtn', 215.2045453663037),
#  ('neighborhood_Blueste', 0.0),
#  ('neighborhood_BrDale', 0.0),
#  ('neighborhood_BrkSide', 793.4363076934152),
#  ('neighborhood_ClearCr', 500.4340229002719),
#  ('neighborhood_CollgCr', 0.0),
#  ('neighborhood_Crawfor', 2926.221874705579),
#  ('neighborhood_Edwards', -0.0),
#  ('neighborhood_Gilbert', -0.0),
#  ('neighborhood_Greens', 0.0),
#  ('neighborhood_GrnHill', 2624.156616037899),
#  ('neighborhood_IDOTRR', -0.0),
#  ('neighborhood_Landmrk', 0.0),
#  ('neighborhood_MeadowV', -362.3750575788724),
#  ('neighborhood_Mitchel', -0.0),
# ...
